# %%
std1={}

# %%
type(std1)
# Out:
# dict

# %%
std1["Name"]="Abrar Morshed"

# %%
std1
# Out:
# {'Name': 'Abrar Morshed'}

# %%
std1["Id"]=4554656
std1["Age"]=23

# %%
std1

# %%
std1["Name"]
# Out:
# 'Abrar Morshed'

# %%
std2={"Name":"Ahad Mahmud","Age":23,"ID":2350485,"MIS101":"A","CSE101":"A+","MIS305":"A"}

# %%
std2
# Out:
# {'Name': 'Ahad Mahmud',
#  'Age': 23,
#  'ID': 2350485,
#  'MIS101': 'A',
#  'CSE101': 'A+',
#  'MIS305': 'A'}

# %%
saarc={"Name":["Bangladesh","Afganisthan","Pakisthan","Nepal","Bhutan","India","Sri Lanka","Maldiv"],"GDP":[255364,75981,9753,74559,7456,78516,78954,98765],"Ppl":[41455,7575265,6575,578552,997,78564,457865,97865]}

# %%
saarc
# Out:
# {'Name': ['Bangladesh',
#   'Afganisthan',
#   'Pakisthan',
#   'Nepal',
#   'Bhutan',
#   'India',
#   'Sri Lanka',
#   'Maldiv'],
#  'GDP': [255364, 75981, 9753, 74559, 7456, 78516, 78954, 98765],
#  'Ppl': [41455, 7575265, 6575, 578552, 997, 78564, 457865, 97865]}

# %%
import pandas as pd

# %%
saarc=pd.DataFrame(saarc)

# %%
saarc
# Out:
#           Name     GDP      Ppl
# 0   Bangladesh  255364    41455
# 1  Afganisthan   75981  7575265
# 2    Pakisthan    9753     6575
# 3        Nepal   74559   578552
# 4       Bhutan    7456      997
# 5        India   78516    78564
# 6    Sri Lanka   78954   457865
# 7       Maldiv   98765    97865

# %%
std3=std2.copy()

# %%
std3
# Out:
# {'Name': 'Ahad Mahmud',
#  'Age': 23,
#  'ID': 2350485,
#  'MIS101': 'A',
#  'CSE101': 'A+',
#  'MIS305': 'A'}

# %%
std2.fromkeys("ID")
# Out:
# {'I': None, 'D': None}

# %%
std2.items()
# Out:
# dict_items([('Name', 'Ahad Mahmud'), ('Age', 23), ('ID', 2350485), ('MIS101', 'A'), ('CSE101', 'A+'), ('MIS305', 'A')])

# %%
std2.keys()
# Out:
# dict_keys(['Name', 'Age', 'ID', 'MIS101', 'CSE101', 'MIS305'])

# %%
std2.pop("Name")
# Out:
# 'Ahad Mahmud'

# %%
std2
# Out:
# {'Age': 23, 'ID': 2350485, 'MIS101': 'A', 'CSE101': 'A+', 'MIS305': 'A'}

# %%
std2.popitem()
# Out:
# ('MIS305', 'A')

# %%
std2.update({"MIS101":"A+"})

# %%
std2
# Out:
# {'Age': 23, 'ID': 2350485, 'MIS101': 'A+', 'CSE101': 'A+'}

# %%
45>565
# Out:
# False

# %%
535>454
# Out:
# True

# %%
34<23
# Out:
# False

# %%
43<45
# Out:
# True

# %%
3==2
# Out:
# False

# %%
3==3
# Out:
# True

# %%
23!=2
# Out:
# True

# %%
x=3
if x>2:
    print("OK")
# Out:
# OK
